# %%
from training.dataset import MLMDataset
from scripts.load_corpus import load_tokenized_corpus
from tokenizer.build_vocab import build_vocab

# %%
VOCAB_SIZE = 10_000
SEQ_LEN = 128

# %%
tokenized_corpus = load_tokenized_corpus()

# %%
vocab = build_vocab(tokenized_corpus, VOCAB_SIZE)

# %%
dataset = MLMDataset(tokenized_corpus, vocab, SEQ_LEN)

# %%
dataset[0]['labels']
# Out:
# [-100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  402,
#  -100,
#  -100,
#  33,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  0,
#  -100,
#  -100,
#  0,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  0,
#  0,
#  0,
#  -100,
#  -100,
#  -100,
#  0,
#  -100,
#  -100,
#  0,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  0,
#  -100,
#  0,
#  -100,
#  0,
#  0,
#  -100,
#  -100,
#  -100,
#  -100,
#  0,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  0,
#  -100,
#  0,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  0,
#  -100,
#  -100,
#  -100,
#  -100,
#  0,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  -100,
#  0,
#  -100]
